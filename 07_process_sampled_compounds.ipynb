# %% [markdown]
# You need to process all 200 million sampled SMILES. The provided script '07a_process_sampled_compounds.py' does the job for you. It takes the epoch number as an argument and then process the SMILES and calculates the fingerprints, and basic descriptors.

# %% [markdown]
# This is very easy to parallize and you can use your cluster and submit every job to it. E.g: Copy psate the commands to the cluster and run it

# %%
for i in range(1,201):
    command = f"srun python 07a_process_sampled_compounds.py {i} &"
    print(command)
# Out:
# srun python 07a_process_sampled_compounds.py 1 &
# srun python 07a_process_sampled_compounds.py 2 &
# srun python 07a_process_sampled_compounds.py 3 &
# srun python 07a_process_sampled_compounds.py 4 &
# srun python 07a_process_sampled_compounds.py 5 &
# srun python 07a_process_sampled_compounds.py 6 &
# srun python 07a_process_sampled_compounds.py 7 &
# srun python 07a_process_sampled_compounds.py 8 &
# srun python 07a_process_sampled_compounds.py 9 &
# srun python 07a_process_sampled_compounds.py 10 &
# srun python 07a_process_sampled_compounds.py 11 &
# srun python 07a_process_sampled_compounds.py 12 &
# srun python 07a_process_sampled_compounds.py 13 &
# srun python 07a_process_sampled_compounds.py 14 &
# srun python 07a_process_sampled_compounds.py 15 &
# srun python 07a_process_sampled_compounds.py 16 &
# srun python 07a_process_sampled_compounds.py 17 &
# srun python 07a_process_sampled_compounds.py 18 &
# srun python 07a_process_sampled_compounds.py 19 &
# ...

# %% [markdown]
# The next step is to run the nearest neighbor analysis. For this you can either run the '08_nn_calculation.ipynb' locally or use the '08a_nn_calculation.py' script analogous to the '08a_process_sampled_compounds.py' script
